# %% [markdown]
# # Integer arithmetics
# ### We already know the following operators which may be applied to numbers: +, -, * and **.
# ### The division operator / for integers gives a floating-point real number (an object of type float).
# ### The exponentiation ** also returns a float when the power is negative:

# %%
print(17 / 3)  # gives 5.66666666667
print(2 ** 4)  # gives 16
print(2 ** -2) # gives 0.25

# %% [markdown]
# ### There's a special operation for integer division where the remainder is discarded: //.
# ### The operation that yields a remainder of such a division looks like %.
# ### Both operation always yield an object of type int.

# %%
print(17 / 3)   # gives 5.66666666667
print(17 // 3)  # gives 5
print(17 % 3)   # gives 2

# %% [markdown]
# # Floating-point numbers
# ### When we read an integer value, we read a line with input() and then cast a string to integer using int().
# ### When we read a floating-point number, we need to cast the string to float using float():

# %%
x = float(input())
print(int(x))
# Out:
#  45678.45678
# 45678

# %%
print(int(1.3))   # gives 1
print(int(1.7))   # gives 1
print(int(-1.3))  # gives -1
print(int(-1.7))  # gives -1

# %% [markdown]
# ### There's also a function round() that performs the usual rounding:

# %% [markdown]
# ### Floating-point real numbers can't be represented with exact precision due to hardware limitations.
# ### This can lead to cumbersome effects. See the Python docs for the details.

# %%
print(0.1 + 0.2)  # gives 0.30000000000000004
# Out:
# 0.30000000000000004

# %% [markdown]
# # math module
# ### Python has many auxiliary functions for calculations with floats. They can be found in the math module.
# ### To use this module, we need to import it first by writing the following instruction at the beginning of the program:

# %%
import math
x = math.sqrt("4")

print(x)
print(math.ceil(1 + 3.8))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 import math
# ----> 2 x = math.sqrt("4")
#       4 print(x)
#       5 print(math.ceil(1 + 3.8))
#
# TypeError: must be real number, not str

# %% [markdown]
# ![image.png](attachment:01968082-1228-4c51-a2ab-181a59f3643f.png)

# %% [markdown]
# # Exercise 1: Last digit of the integer
# ### Given an integer number, print its last digit

# %% [markdown]
# # Exercise 2: Tens digit
# ### Given an positive integer. Print its tens digit.

# %% [markdown]
# # Exercise 3: Sum of digits
# ### Given a three-digit number. Find the sum of its digits.

# %% [markdown]
# # Exercise 4: Fractional part
# ### Given a positive real number, print its fractional part.

# %% [markdown]
# # Exercise 5: First digit after decimal point
# ### Given a positive real number, print its first digit to the right of the decimal point.

# %% [markdown]
# # Exercise 6: Car route
# ### A car can cover distance of N kilometers per day.
# ### How many days will it take to cover a route of length M kilometers? The program gets two numbers: N and M.

# %% [markdown]
# # Exercise 7:Digital clock
# ### Given the integer N - the number of minutes that is passed since midnight
# #### how many hours and minutes are displayed on the 24h digital clock?
# ### The program should print two numbers: the number of hours (between 0 and 23) and the number of minutes (between 0 and 59).
# ### For example, if N = 150, then 150 minutes have passed since midnight - i.e. now is 2:30 am. So the program should print 2 30

# %% [markdown]
# # Exercise 8 :Total cost
# ### A cupcake costs A dollars and B cents.
# ### Determine, how many dollars and cents should one pay for N cupcakes.
# ### A program gets three numbers: A, B, N.
# ### It should print two numbers: total cost in dollars and cents.

# %% [markdown]
# # Exercise 9: Clock face - 1
# ### H hours, M minutes and S seconds are passed since the midnight (0 ≤ H < 12, 0 ≤ M < 60, 0 ≤ S < 60).
# ### Determine the angle (in degrees) of the hour hand on the clock face right now.

# %% [markdown]
# # Exercise 10: Clock face - 2
# ### Hour hand turned by α degrees since the midnight.
# ### Determine the angle by which minute hand turned since the start of the current hour.
# ### Input and output in this problems are floating-point numbers.
